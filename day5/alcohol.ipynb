# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarizes as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
print(drinks)
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
beer_avg = drinks.groupby('continent').beer_servings.mean()
print(beer_avg.idxmax())
# Out:
# EU

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
wine_avg = drinks.groupby('continent').wine_servings.mean()
print(wine_avg)
# Out:
# continent
# AF     16.264151
# AS      9.068182
# EU    142.222222
# OC     35.625000
# SA     62.416667
# Name: wine_servings, dtype: float64

# %% [markdown]
# ### Step 6. Print the mean alcoohol consumption per continent for every column

# %%
alcohol_avg = drinks.groupby('continent').total_litres_of_pure_alcohol.mean()
print(alcohol_avg)
# Out:
# continent
# AF    3.007547
# AS    2.170455
# EU    8.617778
# OC    3.381250
# SA    6.308333
# Name: total_litres_of_pure_alcohol, dtype: float64

# %% [markdown]
# ### Step 7. Print the median alcoohol consumption per continent for every column

# %%
tot_med = drinks.groupby('continent').total_litres_of_pure_alcohol.median()
print(tot_med)
# Out:
# continent
# AF     2.30
# AS     1.20
# EU    10.00
# OC     1.75
# SA     6.85
# Name: total_litres_of_pure_alcohol, dtype: float64

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
spirit_min = drinks.spirit_servings.min()
spirit_max = drinks.spirit_servings.max()
spirit_mean = drinks.spirit_servings.mean()
print(spirit_min,"\n", spirit_max, "\n", spirit_mean)
# Out:
# 0
#  438
#  80.99481865284974
